# %%
from ISLP import load_data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
import plotly
# %matplotlib inline

# %% [markdown]
# # College Dataset

# %%
College = load_data('College')
College.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
College.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
sns.pairplot(College[['Top10perc', 'Apps', 'Enroll']])
plt.show()

# %%
pd.plotting.scatter_matrix(College[['Top10perc', 'Apps', 'Enroll']])
plt.show()

# %%
College[['Private','Outstate']].plot.box(by='Private')
plt.show()
# Out:
# C:\Users\SHANTANU SRIVASTAV\AppData\Local\Temp\ipykernel_13752\1029752421.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
sns.boxplot(College,x='Private',y='Outstate')
plt.show()

# %%
College["Elite"]=pd.cut(College['Top10perc'],[0,50,100],labels =['No', 'Yes'])

# %%
College['Top10perc']>50
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 772    False
# 773    False
# 774    False
# 775     True
# 776    False
# Name: Top10perc, Length: 777, dtype: bool

# %%
print(College['Elite'].value_counts())
College.head(2)
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate Elite
# 0       18.1           12    7041         60    No
# 1       12.2           16   10527         56    No

# %%
sns.boxplot(College,x='Elite',y='Outstate')
plt.show()

# %%
College.head(1)
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60

# %%
College[['Outstate','Enroll']]
# Out:
#      Outstate  Enroll
# 0        7440     721
# 1       12280     512
# 2       11250     336
# 3       12960     137
# 4        7560      55
# ..        ...     ...
# 772      6797     543
# 773     11520     695
# 774      6900     695
# 775     19840    1317
# 776      4990     691
#
# [777 rows x 2 columns]

# %%
fig,ax=plt.subplots(2,2,figsize=(14,6))
College['Accept'].plot.hist(ax=ax[0,0],bins=20,rwidth=0.8,alpha=0.9,color='red').legend()
College['Enroll'].plot.hist(ax=ax[0,1],bins=20,rwidth=0.8,color='blue').legend()
College['Outstate'].plot.hist(ax=ax[1,0],bins=20,rwidth=0.8,color='green').legend()
College['Top10perc'].plot.hist(ax=ax[1,1],bins=20,rwidth=0.8,color='violet').legend()
plt.tight_layout()

# %% [markdown]
# # Auto DataSet

# %%
auto=load_data('Auto')
auto.reset_index(inplace=True)
auto.head(2)
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0         130
# 1          buick skylark 320  15.0          8         350.0         165
#
#    weight  acceleration  year  origin
# 0    3504          12.0    70       1
# 1    3693          11.5    70       1

# %%
print(auto.shape)
auto.info()
# Out:
# (392, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          392 non-null    object
#  1   mpg           392 non-null    float64
#  2   cylinders     392 non-null    int64
#  3   displacement  392 non-null    float64
#  4   horsepower    392 non-null    int64
#  5   weight        392 non-null    int64
#  6   acceleration  392 non-null    float64
#  7   year          392 non-null    int64
#  8   origin        392 non-null    int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
auto.nunique()
# Out:
# name            301
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# year             13
# origin            3
# dtype: int64

# %%
auto.isnull().any(axis=1).sum() == 0
# Out:
# True

# %%
qual=['name','cylinders','origin']

# %%
auto.drop(columns=qual).describe().loc[['min','max','mean']]
# Out:
#             mpg  displacement  horsepower       weight  acceleration  \
# min    9.000000      68.00000   46.000000  1613.000000      8.000000
# max   46.600000     455.00000  230.000000  5140.000000     24.800000
# mean  23.445918     194.41199  104.469388  2977.584184     15.541327
#
#            year
# min   70.000000
# max   82.000000
# mean  75.979592

# %%
auto.drop(columns=qual).describe().loc[['mean','std']]
# Out:
#             mpg  displacement  horsepower       weight  acceleration  \
# mean  23.445918    194.411990  104.469388  2977.584184     15.541327
# std    7.805007    104.644004   38.491160   849.402560      2.758864
#
#            year
# mean  75.979592
# std    3.683737

# %%
auto.drop(index=range(10,85),columns=qual).describe().loc[['mean','std']]
# Out:
#             mpg  displacement  horsepower       weight  acceleration  \
# mean  24.374763    187.880126  101.003155  2938.854890     15.704101
# std    7.872565    100.169973   36.003208   811.640668      2.719913
#
#            year
# mean  77.123028
# std    3.127158

# %%
sns.pairplot(auto)

# %% [markdown]
# # Boston

# %%
boston= load_data('Boston')
print(boston.shape)
boston.head(2)
# Out:
# (506, 13)
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6

# %%
sns.pairplot(boston)
